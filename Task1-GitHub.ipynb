# %% [markdown]
# # Data Wrangling Project
# ## Cleaning a Job Postings Data Set
# #### Scott Lee
#
#
# Date: 14/06/2021
#
# Version: 1.0
#
# Environment: Python 3.8.3 and Jupyter notebook
#
# Libraries used: please include the main libraries you used in your assignment here, e.g.,:
# * pandas
# * re
# * numpy
# * datetime
# * difflib
# * Collections

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import re

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

from datetime import datetime

df = pd.read_csv('dataset1_with_error.csv')

# %% [markdown]
# Taking a quick look at the dataframe so we know what we need to clean.

# %%
df
# Out:
#              Id                                              Title  \
# 0      12612628                        Engineering Systems Analyst
# 1      12612830                            Stress Engineer Glasgow
# 2      12612844                   Modelling and simulation analyst
# 3      12613049  Engineering Systems Analyst / Mathematical Mod...
# 4      12613647         Pioneer, Miser Engineering Systems Analyst
# ...         ...                                                ...
# 55164  72705203                TEACHER OF BUSINESS STUDIES AND LAW
# 55165  72705205       Pensions Administrators (Temporary/Contract)
# 55166  72705221                           Senior Financial Advisor
# 55167  72705240    Barclays Future Leaders Development Programmes
# 55168  72705244  Quality Assurance Environmental Manager Nottin...
#
#          Location                       Company ContractType ContractTime  \
# 0         Dorking  Gregory Martin International          NaN    permanent
# 1         Glasgow  Gregory Martin International          NaN    permanent
# 2       Hampshire  Gregory Martin International          NaN    permanent
# 3          Surrey  Gregory Martin International          NaN    permanent
# 4          Surrey  Gregory Martin International          NaN    permanent
# ...           ...                           ...          ...          ...
# 55164   Salisbury                                                contract
# 55165          UK                    Abenefit2u          NaN     contract
# 55166      London        Fram Executive Search.            -    permanent
# 55167     Hackney                      Barclays            -            -
# 55168  Nottingham      Stephen James Consulting          NaN    permanent
#
#                         Category   Salary         OpenDate        CloseDate  \
# 0               Engineering Jobs    25000  20130708T120000  20130906T120000
# 1               Engineering Jobs    30000  20120130T000000  20120330T000000
# 2               Engineering Jobs    30000  20121221T150000  20130120T150000
# 3               Engineering Jobs    27500  20131208T150000  20140206T150000
# 4               Engineering Jobs    25000  20130302T120000  20130501T120000
# ...                          ...      ...              ...              ...
# 55164              Teaching Jobs    22800  20120123T120000  20120206T120000
# 55165  Accounting & Finance Jobs    24000  20130801T150000  20130831T150000
# 55166  Accounting & Finance Jobs    40000  20130126T000000  20130225T000000
# 55167                    IT Jobs    36000  20121223T150000  20130221T150000
# 55168  Healthcare & Nursing Jobs  35000.0  20120110T150000  20120409T150000
#
#                     Source
# 0         cv-library.co.uk
# 1         cv-library.co.uk
# 2         cv-library.co.uk
# 3         cv-library.co.uk
# 4         cv-library.co.uk
# ...                    ...
# 55164           hays.co.uk
# 55165     cv-library.co.uk
# 55166  ifaonlinejobs.co.uk
# 55167           grb.uk.com
# 55168        tntjobs.co.uk
#
# [55169 rows x 11 columns]

# %% [markdown]
# There are a couple of observations here:
# <br> If something like a company name or job description is spelt wrong that will impact the analysis.
# <br> The date formats are not easily readable.
# <br> There are missing values.

# %% [markdown]
# ## Task 1: Auditing and cleansing the loaded data
# <br>
# Here we are going to have a look at the low frequency company names. This can help to give us an idea if a name may have been spelt wrong.

# %%
#check the similar between two string
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

from collections import Counter
    
# find the high frequency location to low frequency location
def match_highfreq_To_lowfreq(data, min_threshold, max_threshold):
    # check low frequency company names
    lowfreq_data_list = [k for k,v in Counter(data).items() if v<=5]
    print ("Number of lowfreq_data", len(lowfreq_data_list))
    highfreq_data_list = list(set(data[~(data.isnull())]).difference(lowfreq_data_list))
    print ("Number of highfreq_data", len(highfreq_data_list))
    # the printed data tells that probably not many companies posted more than 5 jobs in those years.


    match_data={}
    for lowfreq_data in lowfreq_data_list:
        for highfreq_data in highfreq_data_list:
            ratio = similar(lowfreq_data.upper(), highfreq_data.upper())
            if ratio >= min_threshold and ratio <= max_threshold:
                match_data[lowfreq_data] = highfreq_data
                print(lowfreq_data, ":", highfreq_data, ratio)
    return match_data

# %% [markdown]
# ## Id column
# Some observations before we begin:
# <br> Are all the records the same data type and length?
# <br> Are they all unique?
# <br> We will investigate below.

# %%
type(df.iloc[1,0])
#DF.id is an integer

#Handling the Id column. Confirming data type is int and that all Id's are 8 digits in length

test = df

holding_list = []
for item in test.Id:
    item = str(item)
    if len(item) == 8:
        pass
    else:
        print('Fail')
        holding_list.append(item)
if len(holding_list)>0:
    print('Warning, there is an error')
else:
    print("All Id's are integer of length 8")

df.Id.astype(int)

print('The number of unique id entries are', len(df.Id.unique()))
print('This is equal to the number of rows, thus all are unique')
# Out:
# All Id's are integer of length 8
# The number of unique id entries are 55169
# This is equal to the number of rows, thus all are unique

# %% [markdown]
# ## Title Column
# <br> Their are job titles that semantically mean the same thing but are written differently. E.g. "software engineer" and "Software Engineer",
# <br> Also there are location names that appear in a job title, e.g. "Analyst - London", needs to be "Analyst" with "London moved to a different field.

# %%
#Cleaning up and normalising the title data
def clean_title(job_title):
    if pd.isnull(job_title):
        return job_title
    else:
        #Normalise to uppercase letters
        job_title = job_title.upper()
        #Remove special characters at the end
        job_title = re.sub(r"\W+$", "", job_title) 
        #Remove all special charactrs except space and dot
        #Included "+" charcter and "/" charcter as they are relevant e.g. a C++ programer job loses meaning without "++"
        job_title = re.sub(r'([^\w\s\.\+\/]|_)', '', job_title)
        #Replace multiple spaces with a single space aksi turn spaces on both sides
        job_title = re.sub('\s+', ' ', job_title).strip()
        return job_title

    
print(len(df.Title))
df['TitleNormalised'] = df.Title.apply(lambda x: clean_title(x))
print(len(set(df.TitleNormalised)), 'different job titles after normalisation')


#Remove location names if they appear in the job title column, i.e. redundent data.

for i in range(0, len(df.Id)):
    title_desc = df.iloc[i,11]
    title_loc = df.iloc[i,2].upper()
    if df.iloc[i,2].upper() in df.iloc[i,11]:
        title_desc_new = title_desc.replace(title_loc, '')
        df.iloc[i,11] = title_desc_new
    else:
        title_desc_new = title_desc
        df.iloc[i,11] = title_desc_new
        
#Drop Title column as correct data is migrated to 'TitleNormalised'
df.drop('Title', axis = 1, inplace = True)
# Out:
# 55169
# 55165 different job titles after normalisation

# %% [markdown]
# Below we will use some NLP techniques to check for job names that essentially match. If the job name mateches to a 95% threshold, we will merge the low frequency instances with the high frequency incidents.

# %%
match_data=match_highfreq_To_lowfreq(df.TitleNormalised, 0.95, 1)
# Out:
# Number of lowfreq_data 52447
# Number of highfreq_data 117
# BUSINESS DEVELOPMENT MANAGER : BUSINESS DEVELOPMENT MANAGER  0.9824561403508771
# CARE ASSISTANTS  : CARE ASSISTANT  0.967741935483871
# STAFF NURSE RGN  K : STAFF NURSE RGN   0.9714285714285714
# SUPPORT WORKER : SUPPORT WORKER  0.9655172413793104
# STAFF NURSE RGN : STAFF NURSE RGN  0.967741935483871
# NIGHT NURSE : NIGHT NURSE  0.9565217391304348
# CARE HOME MANAGER : CARE HOME MANAGER  0.9714285714285714
# HOME MANAGER : HOME MANAGER  0.96
# DEPUTY NURSING HOME MANAGER : DEPUTY NURSING HOME MANAGER  0.9818181818181818
# STAFF NURSE : STAFF NURSE  0.9565217391304348
# CARE ASSISTANT : CARE ASSISTANT  0.9655172413793104
# OCCUPATIONAL THERAPIST : OCCUPATIONAL THERAPIST  0.9777777777777777
# REGISTERED NURSE  RGN : REGISTERED NURSE RGN  0.9523809523809523
# REGISTERED MANAGER : REGISTERED MANAGER  0.972972972972973
# STAFF NURSES  : STAFF NURSE  0.96
# NURSING HOME MANAGER : NURSING HOME MANAGER  0.975609756097561
# DEPUTY MANAGER : DEPUTY MANAGER  0.9655172413793104
# UNIT MANAGER : UNIT MANAGER  0.96
# RGN HOME MANAGER : RGN HOME MANAGER  0.9696969696969697
# DEPUTY MANAGER RGN : DEPUTY MANAGER RGN  0.972972972972973
# REGISTERED NURSE : REGISTERED NURSE  0.9696969696969697
# REGISTERED GENERAL NURSE : REGISTERED GENERAL NURSE  0.9795918367346939
# REGISTERED GENERAL NURSE : REGISTERED GENERAL NURSE   0.96
# DEPUTY MANAGER  K : DEPUTY MANAGER   0.9696969696969697
# RGN STAFF NURSES  : RGN STAFF NURSE  0.9696969696969697
# PRACTICE MANAGER : PRACTICE MANAGER  0.9696969696969697
# RGN NIGHTS : RGN NIGHTS  0.9523809523809523
# STAFF NURSES NURSING HOME : STAFF NURSE NURSING HOME  0.96
# REGISTERED MANAGER LD : REGISTERED MANAGER  0.95
# RGN STAFF NURSE : RGN STAFF NURSE  0.967741935483871
# SALES MANAGER : SALES MANAGER  0.9629629629629629
# DEPUTY CARE HOME MANAGER : DEPUTY CARE HOME MANAGER  0.9795918367346939
# CARE COORDINATOR : CARE COORDINATOR  0.9696969696969697
# STAFF NURSE  NURSING HOME : STAFF NURSE NURSING HOME  0.96
# REGISTERED GENERAL NURSES : REGISTERED GENERAL NURSE  0.96
# HEALTH CARE ASSISTANT : HEALTHCARE ASSISTANT  0.9523809523809523
# HEALTH CARE ASSISTANT : HEALTH CARE ASSISTANTS  0.9545454545454546
# HEALTH CARE ASSISTANT : HEALTH CARE ASSISTANT  0.9767441860465116
# LIVE IN CARE WORKER JOB  : LIVE IN CARE WORKER JOBS  0.9795918367346939
# BUSINESS ANALYST : BUSINESS ANALYST  0.9696969696969697
# NURSING HOME MANAGER  K : NURSING HOME MANAGER  0.9545454545454546
# LETTINGS MANAGER : LETTINGS MANAGER  0.9696969696969697
# SALES EXCUTIVE  : SALES EXECUTIVE  0.967741935483871
# MORTGAGE ADVISOR : MORTGAGE ADVISOR  0.9696969696969697
# SENIOR ACCOUNT MANAGERS : SENIOR ACCOUNT MANAGER  0.9565217391304348
# GENERAL MANAGER : GENERAL MANAGER  0.967741935483871
# REGISTERED GENERAL NURSE / STAFF NURSE RGN : REGISTERED GENERAL NURSE / STAFF NURSE RGN  0.9882352941176471
# BUSINESS DEVELOPMENT MANAGER M E : BUSINESS DEVELOPMENT MANAGER  0.9508196721311475
# RGN NIGHTS   : RGN NIGHTS  0.9565217391304348
# NIGHT NURSE   : NIGHT NURSE  0.96
# REGISTERED NURSE RMN   : REGISTERED NURSE RN  0.9523809523809523
# ASSISTANT RESTAURANT MANAGER : ASSISTANT RESTAURANT MANAGER  0.9824561403508771
# FEMALE SUPPORT WORKER  : MALE SUPPORT WORKER  0.9523809523809523
# SENIOR ACCOUNT MANAGER K : SENIOR ACCOUNT MANAGER  0.9787234042553191
# CARER ASSISTANT JOBS  : CARE ASSISTANT JOB  0.95
# CARER ASSISTANT JOBS  : CARE ASSISTANT JOBS  0.975609756097561
# REGISTERED GENERAL NURSES RGN : REGISTERED GENERAL NURSE RGN  0.9655172413793104
# REGISTERED NURSE RMN BARCHESTER HEALTHCARE  : REGISTERED NURSE RGN BARCHESTER HEALTHCARE  0.9767441860465116
# SENIOR ACCOUNT MANAGER PR : SENIOR ACCOUNT MANAGER  0.9583333333333334
# BUSINESS DEVELOPMENT MANAGER FM : BUSINESS DEVELOPMENT MANAGER  0.9666666666666667
# BUSINESS DEVELOPMENT MANAGER IBM : BUSINESS DEVELOPMENT MANAGER  0.9508196721311475
# CLINICAL LEAD   : CLINICAL LEAD  0.9655172413793104
# X REGISTERED GENERAL NURSE  : REGISTERED GENERAL NURSE  0.9615384615384616
# ASSISTANT RESTAURANT MANAGER K : ASSISTANT RESTAURANT MANAGER  0.9830508474576272
# REGISTERED NURSES RGN  : REGISTERED NURSE RGN  0.9767441860465116
# REGISTERED NURSES RGN  : REGISTERED NURSE RN  0.9523809523809523
# HEALTHCARE ASSISTANT   : HEALTHCARE ASSISTANT  0.9767441860465116
# HEALTHCARE ASSISTANT   : HEALTHCARE ASSISTANTS  0.9545454545454546
# HEALTHCARE ASSISTANT   : HEALTH CARE ASSISTANT  0.9545454545454546
# OCCUPATIONAL HEALTH ADVISOR : OCCUPATIONAL HEALTH ADVISOR  0.9818181818181818
# HEALTH CARE ASSISTANTS : HEALTH CARE ASSISTANTS  0.9777777777777777
# HEALTH CARE ASSISTANTS : HEALTHCARE ASSISTANTS  0.9545454545454546
# HEALTH CARE ASSISTANTS : HEALTH CARE ASSISTANT  0.9545454545454546
# SUBSTANCE MISUSE NURSE : SUBSTANCE MISUSE NURSE  0.9777777777777777
# STAFF NURSE NURSING HOME : STAFF NURSE NURSING HOME  0.9795918367346939
# REGISTERED GENERAL NURSE RGN X : REGISTERED GENERAL NURSE RGN  0.9830508474576272
# STAFF NURSE RGN OR RMN : STAFF NURSE RGN OR RMN  0.9777777777777777
# STAFF NURSE RGN OR RMN : STAFF NURSE RGN OR RMN   0.9565217391304348
# REGISTERED NURSE RGNPT BARCHESTER HEALTHCARE : REGISTERED NURSE RGN BARCHESTER HEALTHCARE  0.9655172413793104
# X BUSINESS DEVELOPMENT MANAGERS  : BUSINESS DEVELOPMENT MANAGER  0.9508196721311475
# ASSISTANT MANAGER : ASSISTANT MANAGER  0.9714285714285714
# BUSINESS DEVELOPENT MANAGER : BUSINESS DEVELOPMENT MANAGER  0.9642857142857143
# OPTOMETRIST : OPTOMETRIST  0.9565217391304348
# OPTICAL ASSISTANT : OPTICAL ASSISTANT  0.9714285714285714
# RGN NURSE HOSPITAL  : RGN NURSES HOSPITALS  0.95
# NURSING HOME MANAGER   : NURSING HOME MANAGER  0.9767441860465116
# REGISTERED NURSES   : REGISTERED NURSES  0.972972972972973
# REGISTERED NURSES   : REGISTERED NURSE   0.972972972972973
# RGN STAFF NURSE   : RGN STAFF NURSE  0.9696969696969697
# REGISTERED NURSE RMN  : REGISTERED NURSE RGN  0.9523809523809523
# REGISTERED NURSE RMN  : REGISTERED NURSE RN  0.975609756097561
# BUSINESS DEVELOPEMENT MANAGER : BUSINESS DEVELOPMENT MANAGER  0.9655172413793104
# REGISTERED NURSE RGND BARCHESTER HEALTHCARE : REGISTERED NURSE RGN BARCHESTER HEALTHCARE  0.9767441860465116
# OPTOMETRIST  KK : OPTOMETRIST  K K 0.967741935483871
#  REGISTERED GENERAL NURSE : REGISTERED GENERAL NURSE  0.96
# OCCUPATIONAL HEALTH ADVISOR   : OCCUPATIONAL HEALTH ADVISOR  0.9824561403508771
# SUPPORT WORKER/  : SUPPORT WORKER  0.967741935483871
# CARE ASSISTANT/  : CARE ASSISTANT  0.967741935483871
# CHEF DE PARTIE : CHEF DE PARTIE  0.9655172413793104
# REGISTRED GENERAL NURSE : REGISTERED GENERAL NURSE  0.9583333333333334
# DEPUTY MANAGERS  : DEPUTY MANAGER  0.967741935483871
# QUALIFIED DISPENSING OPTICIAN : QUALIFIED DISPENSING OPTICIAN  0.9830508474576272
# HEAD CHEF K : HEAD CHEF  0.9523809523809523
# REGISTERED GENERAL NURSES RGN  : REGISTERED GENERAL NURSE RGN  0.9830508474576272
# DEPUTY MANAGER RGN   : DEPUTY MANAGER RGN  0.9743589743589743
# HEALTH CARE ASSISTANT HCA   : HEALTH CARE ASSISTANT HCA  0.9811320754716981
# DEPUTY MANAGER  ELDERLY NURSING HOME  : DEPUTY MANAGER  ELDERLY NURSING HOME 0.9863013698630136
# BUSINESS DEVELOPMENT MANAGER BMS : BUSINESS DEVELOPMENT MANAGER  0.9508196721311475
# STAFF NURSE RGN  PER HOUR : STAFF NURSE RGN  PER HOUR  0.9803921568627451
# REGISTERED NURSE RMN : REGISTERED NURSE RN  0.95
# SUPPORT WORKER   : SUPPORT WORKER  0.967741935483871
# STAFF NURSE ELDERLY NURSING HOME   : STAFF NURSE ELDERLY NURSING HOME  0.9850746268656716
# BUSINESS DEVELOPMENT MANAGER  TO : BUSINESS DEVELOPMENT MANAGER  0.9508196721311475
# MALE SUPPORT WORKERS : MALE SUPPORT WORKER  0.95
# DEPUTY CARE HOME MANAGER   : DEPUTY CARE HOME MANAGER  0.9803921568627451
# BUSINESS DEVELOPMENT MANAGER POS : BUSINESS DEVELOPMENT MANAGER  0.9508196721311475
# REGISTERED NURSE X  : REGISTERED NURSE   0.972972972972973
# RGN NURSES  : RGN NURSE  0.9523809523809523
# STAF NURSE RGN  : STAFF NURSE RGN  0.967741935483871
# STAFF NURSE X  : STAFF NURSE   0.9629629629629629
# DEPUTY HOME MANAGER   : DEPUTY HOME MANAGER  0.975609756097561
# DEPUTY MANAGER K RGN  : DEPUTY MANAGER RGN  0.95
# HOME MANAGER K  : HOME MANAGER   0.9655172413793104
# REGISTERED GENERAL NURSE RGN/RN  : REGISTERED GENERAL NURSE RGN  0.9508196721311475
#  REGISTERED GENERAL NURSE  : REGISTERED GENERAL NURSE  0.9803921568627451
#  REGISTERED GENERAL NURSE  : REGISTERED GENERAL NURSE   0.9615384615384616
# SALES ADVISOR X : SALES ADVISOR  0.9655172413793104
# DEPUTY NURSING HOME MANAGERS  : DEPUTY NURSING HOME MANAGER  0.9824561403508771
# DEPUTY MANAGER ELDERLY NURSING HOME  : DEPUTY MANAGER  ELDERLY NURSING HOME 0.9722222222222222
# RESTAURANT MANAGER K : RESTAURANT MANAGER  0.9743589743589743
# ASSISTANT RESTAURANT MANAGER  K : ASSISTANT RESTAURANT MANAGER  0.9666666666666667
# RESGISTERED GENERAL NURSE : REGISTERED GENERAL NURSE  0.96
# BUSINESS ANALYST X : BUSINESS ANALYST  0.9714285714285714
# BUSINESS DEVELOPEMNT MANAGER  : BUSINESS DEVELOPMENT MANAGER  0.9655172413793104
# UNIT MANAGER   : UNIT MANAGER  0.9629629629629629
# STAFF NURSE NURSING HOME   : STAFF NURSE NURSING HOME  0.9803921568627451
# DEPUTY HOME MANAGER RN  : DEPUTY HOME MANAGER RGN  0.9787234042553191
# REGISTERED GENERAL NURSE / RGN  : REGISTERED GENERAL NURSE RGN  0.9666666666666667
# DEPUTY MANAGER RGN  P : DEPUTY MANAGER RGN  0.95
# PHLEBOTOMIST : PHLEBOTOMIST  0.96
# NIGHT NURSES  : NIGHT NURSE  0.96
# CARE HOME MANAGER   : CARE HOME MANAGER  0.972972972972973
# BUSINESS ANALYST T : BUSINESS ANALYST  0.9714285714285714
# RMN STAFF NURSE   : RMN STAFF NURSE  0.9696969696969697
# SUPPORT WORKERS   : SUPPORT WORKERS  0.9696969696969697
# REGISTERED GENERAL NURSES  : REGISTERED GENERAL NURSE  0.9803921568627451
# REGISTERED GENERAL NURSES  : REGISTERED GENERAL NURSE   0.9615384615384616
# REGISTERED GENERAL NURSE RGN RN  : REGISTERED GENERAL NURSE RGN  0.9508196721311475
# BUSINESS DEVELOPMENT MANAGER X : BUSINESS DEVELOPMENT MANAGER  0.9830508474576272
# RESTAURANT MANAGER  K : RESTAURANT MANAGER  0.95
# BUSINESS DEVELOPMENT MANAGER TAX : BUSINESS DEVELOPMENT MANAGER  0.9508196721311475
# REGISTERED NURSEBANK  : REGISTERED NURSE BANK  0.9767441860465116
# REGISTERED HOMES MANAGER : REGISTERED HOME MANAGER  0.9583333333333334
# BUISNESS DEVELOPMENT MANAGER  : BUSINESS DEVELOPMENT MANAGER  0.9655172413793104
# RGN NURSE   : RGN NURSE  0.9523809523809523
# REGISTERED MENTAL HEALTH NURSES : REGISTERED MENTAL HEALTH NURSE  0.967741935483871
# HEALTHCARE ASSISTANTS HCA  : HEALTH CARE ASSISTANT HCA  0.9615384615384616
# REGISTRED MANAGER  : REGISTERED MANAGER  0.972972972972973
# HEAD CHEF S : HEAD CHEF  0.9523809523809523
# SALES EXECUTIVES  : SALES EXECUTIVE  0.9696969696969697
# STORE MANAGER : STORE MANAGER  0.9629629629629629
# BUSINESS DEVELOPMENT MANAGER LED : BUSINESS DEVELOPMENT MANAGER  0.9508196721311475
# BUSINESS DEVELOMENT MANAGER : BUSINESS DEVELOPMENT MANAGER  0.9642857142857143
# BUSINESS DEVELOPMENT MANGER : BUSINESS DEVELOPMENT MANAGER  0.9642857142857143
# REGSITERED MENTAL HEALTH NURSE : REGISTERED MENTAL HEALTH NURSE  0.9508196721311475
# HEALTH CARE ASSISTANT HCA : HEALTH CARE ASSISTANT HCA  0.9803921568627451

# %%
df['job_title_resovle_similar'] = df.TitleNormalised.replace(match_data)

# %%
df.drop('TitleNormalised', axis = 1, inplace = True)
df['Title'] = df.job_title_resovle_similar.replace(match_data)
df.drop('job_title_resovle_similar', axis = 1, inplace = True)

# %% [markdown]
# ## Location

# %%
def clean_location(location):
    if pd.isnull(location):
        return location
    else:
        #Normalise to uppercase letters
        location = location.upper()
        #Remove special characters at the end
        location = re.sub(r"\W+$", "", location) 
        #Remove all special charactrs except space and dot
        #Included "+" charcter and "/" charcter as they are relevant e.g. a C++ programer job loses meaning without "++"
        location = re.sub(r'([^\w\s\.\+\/]|_)', '', location)
        #Replace multiple spaces with a single space aksi turn spaces on both sides
        location = re.sub('\s+', ' ', location).strip()
        return location

    
print(len(df.Location))
df['LocationNormalised'] = df.Location.apply(lambda x: clean_location(x))
print(len(set(df.LocationNormalised)), 'different locations after normalisation')

df.drop('Location', axis = 1, inplace = True)

print('Location cloumn is datatype ', type(df.loc[1,'LocationNormalised']))
# Out:
# 55169
# 484 different locations after normalisation
# Location cloumn is datatype  <class 'str'>

# %% [markdown]
# ## Company
# <br> Conducting a similar analysis on the Company column.

# %%
def clean_company(company):
    if pd.isnull(company):
        return company
    else:
        #Normalise to uppercase letters
        company = company.upper()
        #Remove special characters at the end
        company = re.sub(r"\W+$", "", company) 
        #Remove all special charactrs except space and dot
        #Included "+" charcter and "/" charcter as they are relevant e.g. a C++ programer job loses meaning without "++"
        company = re.sub(r'([^\w\s\.\+\/]|_)', '', company)
        #Replace multiple spaces with a single space aksi turn spaces on both sides
        company = re.sub('\s+', ' ', company).strip()
        return company
    
print(len(df.Company))
df['CompanyNormalised'] = df.Company.apply(lambda x: clean_company(x))
print(len(set(df.CompanyNormalised)), 'different companies after normalisation')

df.drop('Company', axis = 1, inplace = True)
# Out:
# 55169
# 8671 different companies after normalisation

# %%
df.CompanyNormalised.value_counts()
# Out:
#                            1540
# UKSTAFFSEARCH               498
# RANDSTAD                    403
# CVBROWSER                   328
# MATCHTECH GROUP PLC         286
#                            ...
# TUI UK IRELAND                1
# SEARCH 4 TECHNOLOGY LTD       1
# SILVERBUG LTD                 1
# SPRING GROUP BRISTON          1
# ADRENALIN LTD                 1
# Name: CompanyNormalised, Length: 8670, dtype: int64

# %%
match_data=match_highfreq_To_lowfreq(df.CompanyNormalised, 0.95, 1)
# Out:
# Number of lowfreq_data 6729
# Number of highfreq_data 1941
# EDSTAFF LTD : EDUSTAFF LTD 0.9565217391304348
# BMS GRADUATE : BMS GRADUATES 0.96
# SOLUTION RECRUITMENT : SOLUTIONS RECRUITMENT 0.975609756097561
# SIGMAR RECRUITMENT : SIGMA RECRUITMENT 0.9714285714285714
# TRAVAIL EMPLYMENT GROUP : TRAVAIL EMPLOYMENT GROUP 0.9787234042553191
# SHAW HEALTH CARE : SHAW HEALTHCARE 0.967741935483871
# DERBYSHIRE COUNTY COUNCIL 2 : DERBYSHIRE COUNTY COUNCIL 0.9615384615384616
# TRAVAIL EMPLOYMNET GROUP : TRAVAIL EMPLOYMENT GROUP 0.9583333333333334
# ASHTON RECRUITMENT : ASTON RECRUITMENT 0.9714285714285714
# SOLUTIONS2RECRUITMENT : SOLUTIONS RECRUITMENT 0.9523809523809523
# BADENOCHCLARK : BADENOCH CLARK 0.9629629629629629
# ADDITIONAL RESOURCE : ADDITIONAL RESOURCES 0.9743589743589743
# ANGLIAN HOME IMPROVEMENT : ANGLIAN HOME IMPROVEMENTS 0.9795918367346939
# ONE RECRUITMENT : NE RECRUITMENT 0.9655172413793104
# EASY WEB RECRUITMENT : EASYWEB RECRUITMENT 0.9743589743589743
# PRIMETIME RECRUITMENT : PRIME TIME RECRUITMENT 0.9767441860465116
# PROSPER RECRUITMENT : PROSPERO RECRUITMENT 0.9743589743589743
# COYLE PERSONNEL PLC : COYLES PERSONNEL PLC 0.9743589743589743
# RECRUITMENT REVOLUTION.COM LIMITED : RECRUITMENTREVOLUTION.COM LIMITED 0.9850746268656716
# DEERFOOT I.T. RESOURCES LTD : DEERFOOT IT RESOURCES LTD 0.9615384615384616
# SOLUTIONS 4 RECRUITMENT : SOLUTIONS RECRUITMENT 0.9545454545454546
# RETRACK PERSONNEL : RE TRACK PERSONNEL 0.9714285714285714
# INTA PEOPLE : INTAPEOPLE 0.9523809523809523
# SOLUTIONS 2 RECRUITMENT : SOLUTIONS RECRUITMENT 0.9545454545454546
# JAMIE S ITALIAN : JAMIES ITALIAN 0.9655172413793104
# BE PERSONNEL LIMITED : E PERSONNEL LIMITED 0.9743589743589743
# EXIGO RECRUITMENT LTD : ELIGO RECRUITMENT LTD 0.9523809523809523
# CPL HEATHCARE : CPL HEALTHCARE 0.9629629629629629
# AM RECRUITMENT : JAM RECRUITMENT 0.9655172413793104
# BSV RECRUITMENT LTD : BV RECRUITMENT LTD 0.972972972972973
# .MICHAEL PAGE FINANCIAL SERVICES : MICHAEL PAGE FINANCIAL SERVICES 0.9841269841269841
# THREEPEOPLE : THREE PEOPLE 0.9565217391304348
# ANDERS ELITE : ANDERSELITE 0.9565217391304348
# INSPIRE PEOPLE : INSPIRED PEOPLE 0.9655172413793104
# NON STOP RECRUITMENT : NONSTOP RECRUITMENT 0.9743589743589743
# COBURGBANKS : COBURG BANKS 0.9565217391304348
# RESOURCE GROUP : RESOURCES GROUP 0.9655172413793104
# CCITY IT RECRUITMENT : C CITY IT RECRUITMENT 0.975609756097561
# BLUETOWNONLINE : BLUETOWN ONLINE 0.9655172413793104
# BOND RECRUIMENT : BOND RECRUITMENT 0.967741935483871
# WEBRECRUIT LTD : WEB RECRUIT LTD 0.9655172413793104
# TIME 4 RECRUITMENT SOLUTIONS : TIME RECRUITMENT SOLUTIONS 0.9629629629629629
# PEOPLE COM LTD : PEOPLECOM LTD 0.9629629629629629
# RECRUITMENTCONSULATANT.COM : RECRUITMENTCONSULTANT.COM 0.9803921568627451
# REDNAL RECRUITMENT LTD : REAL RECRUITMENT LTD 0.9523809523809523
# D P CONNECT : DP CONNECT 0.9523809523809523
# NON STOP RECRUITMENT LTD : NONSTOP RECRUITMENT LTD 0.9787234042553191
# KIRKHAMYOUNG LTD : KIRKHAM YOUNG LTD 0.9696969696969697
# SPORTSDIRECT : SPORTS DIRECT 0.96

# %%
# replace lower frequent with higher frequent company name
df['Company_resovle_similar'] = df.CompanyNormalised.replace(match_data)

# %%
df['Company'] = df['Company_resovle_similar']
df.drop('Company_resovle_similar', axis = 1, inplace = True)
df.drop('CompanyNormalised', axis = 1, inplace = True)

# %%
len(df.Company.unique())
# Out:
# 8622

# %% [markdown]
# ## Contract Type
# <br> Contract type has some missing data. There is no accurate way of inferring a contract type based off of the other data, so this will need to be dealt with.

# %%
print('The unique values of ContractType are' ,df.ContractType.unique())
print('\n')
print('The value counts of ContractType are: \n', df.ContractType.value_counts())
# Out:
# The unique values of ContractType are [nan '-' ' ' 'full_time' 'part_time']
#
#
# The value counts of ContractType are:
#               14902
# full_time    12303
# -             4720
# part_time     1568
# Name: ContractType, dtype: int64

# %% [markdown]
# There is no way to infer the contract type from the other data so anything that is not labelled will be changed to " Contract Type Not Specified"
# <br>
# Also data types of this column are mixed as both float and strings, so convert all to type string for processing

# %%
#Changing the nan and empty values to a single string value of 'non_specified'
df['ContractType'] = df.ContractType.astype(str)
for i in range(0,len(df['ContractType'])):
    if df.loc[i,'ContractType'] == 'nan':
        df.loc[i,'ContractType'] = 'non_specified'
    elif df.loc[i,'ContractType'] == '-':
        df.loc[i,'ContractType'] = 'non_specified'
    elif df.loc[i,'ContractType'] == ' ':
        df.loc[i,'ContractType'] = 'non_specified'     
    else:
        pass

print('The unique ContractTypes after wrangling:', df.ContractType.unique())
# Out:
# The unique ContractTypes after wrangling: ['non_specified' 'full_time' 'part_time']

# %% [markdown]
# ## Contract_Time

# %%
print('The unique ContractTime values prior to wrangling are: \n', df.ContractTime.unique())

#Amend to nan, '-' and ' ' to a single value of 'non-specified'
df['ContractTime'] = df.ContractTime.astype(str)

for i in range(0,len(df.ContractTime)):
    if df.loc[i,'ContractTime'] == 'nan':
        df.loc[i,'ContractTime'] = 'non-specified'
    if df.loc[i,'ContractTime'] == '-':
        df.loc[i,'ContractTime'] = 'non-specified'
    elif df.loc[i,'ContractTime'] == ' ':
        df.loc[i,'ContractTime'] = 'non-specified'
    else:
        pass

print('The unique values after wrangling are: \n', df.ContractTime.unique())
# Out:
# The unique ContractTime values prior to wrangling are:
#  ['permanent' '-' 'contract' nan ' ']
# The unique values after wrangling are:
#  ['permanent' 'non-specified' 'contract']

# %% [markdown]
# ## Category

# %%
print('The number of unique values: \n', len(df.Category.unique()))
print('\n')
print(df.Category.value_counts())

#Confirm all values a re type string
df['Category'] = df.Category.astype(str)
# Out:
# The number of unique values:
#  8
#
#
# IT Jobs                             14344
# Healthcare & Nursing Jobs            8809
# Engineering Jobs                     8210
# Accounting & Finance Jobs            7138
# Sales Jobs                           5349
# Hospitality & Catering Jobs          4788
# Teaching Jobs                        3779
# PR, Advertising & Marketing Jobs     2752
# Name: Category, dtype: int64

# %% [markdown]
# There are only 8 categories, all of which are strings.
# <br>
# Ok to leave as is.

# %% [markdown]
# ## Open Date and Close Date
# <br> The date format is very inconsistent, will use regular expressions to clean this up.

# %%
#Function to apply regex to open_date and filter out inconsistancies
def clean_open_date(open_date):
    if pd.isnull(open_date):
        return open_date
    
    else:
        open_date = re.sub(r'\d{4}1[3-9]\d{2}T\d+',open_date[0:4] + open_date[6:8] + open_date[4:6] + open_date[8:],open_date)
        open_date = re.sub(r'\d{4}2[0-9]\d{2}T\d+',open_date[0:4] + open_date[6:8] + open_date[4:6] + open_date[8:],open_date)
    return open_date

df['OpenDate'] = df.OpenDate.apply(lambda x: clean_open_date(x))


#For loop to change to the desired format
for i in range(0, len(df.OpenDate)):  
    x = df.loc[i,'OpenDate']
    date = x.split('T')[0]
    time_comp = x.split('T')[1]
    time_comp_new = time_comp[0:2] + ':' + time_comp[2:4] + ':' + time_comp[4:6]
    time_comp_new

    #Remormated date to read into datetime module
    date_read_in = date + " " + time_comp_new

    #Date object
    date_object = datetime.strptime(date_read_in,'%Y%m%d %H:%M:%S')
    df.loc[i,'OpenTimeNormalised'] = date_object

# %%
#Close Date Module
for i in range(0, len(df.CloseDate)):  
    x = df.loc[i,'CloseDate']
    date = x.split('T')[0]
    time_comp = x.split('T')[1]
    time_comp_new = time_comp[0:2] + ':' + time_comp[2:4] + ':' + time_comp[4:6]
    time_comp_new

    #Remormated date to read into datetime module
    date_read_in = date + " " + time_comp_new

    #Date object
    date_object = datetime.strptime(date_read_in,'%Y%m%d %H:%M:%S')
    df.loc[i,'CloseTimeNormalised'] = date_object

# %%
#Drop original open and close date columns
df.drop('OpenDate', axis = 1, inplace = True)
df.drop('CloseDate', axis = 1, inplace = True)

# %% [markdown]
# ## SourceLink
# <br>
# Checking all values are strings, value counts and number of uniques.
# <br>
# Also converting to uppercase and comparing to check for duplicates, then dropping capitals

# %%
#Exploratory analysis:
len_source = len(df.Source.unique())
print('The number of unique source names is: ',len_source)
print('Value count of df.Source: \n', df.Source.value_counts())

count = 0
for i in range(0, len(df.Source)):
    if type(df.loc[i, 'Source']) is str:
        count = count + 1
    else:
        pass
print('The number of values in the data frame that are type string =', count)


count = 0
for i in range(0, len(df.Source)):
    if type(df.loc[i,'Source']) is not str:
        count = count + 1
    else:
        pass
print('The number of values in the data frame that are not type string =', count)
# Out:
# The number of unique source names is:  106
# Value count of df.Source:
#  totaljobs.com        10102
# cv-library.co.uk      7841
# jobsite.co.uk         3630
# cwjobs.co.uk          3132
# staffnurse.com        2778
#                      ...
# workthing.com            5
# scotsman.com             4
# jobs.gponline.com        3
# cvjobstore.com           1
# thegraduate.co.uk        1
# Name: Source, Length: 106, dtype: int64
# The number of values in the data frame that are type string = 55169
# The number of values in the data frame that are not type string = 0

# %%
#Converting to uppercase then comparing to see if any difference. 
#Will then drop upper case column ('Source_Normalised)

for i in range(0,len(df.Source)):
    df.loc[i,'Source'].upper()
    df.loc[i,'Source_Normalised'] = df.loc[i,'Source'].upper()

#Exploritory Analysis
len_source = len(df.Source_Normalised.unique())
print('The number of unique source names is: ',len_source)
print('Value count of df.Source: \n', df.Source_Normalised.value_counts())

count = 0
for i in range(0, len(df.Source_Normalised)):
    if type(df.loc[i, 'Source_Normalised']) is str:
        count = count + 1
    else:
        pass
print('The number of values in the data frame that are type string =', count)


count = 0
for i in range(0, len(df.Source_Normalised)):
    if type(df.loc[i,'Source_Normalised']) is not str:
        count = count + 1
    else:
        pass
print('The number of values in the data frame that are not type string =', count)
# Out:
# The number of unique source names is:  106
# Value count of df.Source:
#  TOTALJOBS.COM        10102
# CV-LIBRARY.CO.UK      7841
# JOBSITE.CO.UK         3630
# CWJOBS.CO.UK          3132
# STAFFNURSE.COM        2778
#                      ...
# GRB.UK.COM               5
# SCOTSMAN.COM             4
# JOBS.GPONLINE.COM        3
# THEGRADUATE.CO.UK        1
# CVJOBSTORE.COM           1
# Name: Source_Normalised, Length: 106, dtype: int64
# The number of values in the data frame that are type string = 55169
# The number of values in the data frame that are not type string = 0

# %%
match_data=match_highfreq_To_lowfreq(df.Source_Normalised,0.7,1)
# Out:
# Number of lowfreq_data 6
# Number of highfreq_data 100
# CVJOBSTORE.COM : JOBSERVE.COM 0.7692307692307693

# %% [markdown]
# Based on the above, I'm satisfied there are is no signiificant level or mis-spellings or typos of names requiring fixing.

# %%
#Drop new column 'Source_Normalised' after analysis
df.drop('Source_Normalised', axis = 1, inplace = True)

# %% [markdown]
# ## Salary

# %%
def clean_salary(salary):
    if pd.isnull(salary):
        return salary
    else:       
        salary = re.sub(r"-","0", salary)
        salary = re.sub(r"nan", "0", salary)
        salary = re.split(r"/",salary)[0]
        salary = re.split(r"\s", salary)[0]
        #salary = re.split(r"[k|K]", salary[0:2])
        salary = re.sub(r"\d+[k|K]", salary[0:2] + '000', salary)
        
        return salary

df['Salary_Normalised'] = df.Salary.apply(lambda x: clean_salary(x))

df.Salary_Normalised = df.Salary_Normalised.astype(float)

# %%
df.drop('Salary', axis = 1, inplace = True)

# %%
df
# Out:
#              Id   ContractType   ContractTime                   Category  \
# 0      12612628  non_specified      permanent           Engineering Jobs
# 1      12612830  non_specified      permanent           Engineering Jobs
# 2      12612844  non_specified      permanent           Engineering Jobs
# 3      12613049  non_specified      permanent           Engineering Jobs
# 4      12613647  non_specified      permanent           Engineering Jobs
# ...         ...            ...            ...                        ...
# 55164  72705203  non_specified       contract              Teaching Jobs
# 55165  72705205  non_specified       contract  Accounting & Finance Jobs
# 55166  72705221  non_specified      permanent  Accounting & Finance Jobs
# 55167  72705240  non_specified  non-specified                    IT Jobs
# 55168  72705244  non_specified      permanent  Healthcare & Nursing Jobs
#
#                     Source                                              Title  \
# 0         cv-library.co.uk                        ENGINEERING SYSTEMS ANALYST
# 1         cv-library.co.uk                                   STRESS ENGINEER
# 2         cv-library.co.uk                   MODELLING AND SIMULATION ANALYST
# 3         cv-library.co.uk  ENGINEERING SYSTEMS ANALYST / MATHEMATICAL MOD...
# 4         cv-library.co.uk          PIONEER MISER ENGINEERING SYSTEMS ANALYST
# ...                    ...                                                ...
# 55164           hays.co.uk                TEACHER OF BUSINESS STUDIES AND LAW
# 55165     cv-library.co.uk         PENSIONS ADMINISTRATORS TEMPORARY/CONTRACT
# 55166  ifaonlinejobs.co.uk                           SENIOR FINANCIAL ADVISOR
# 55167           grb.uk.com     BARCLAYS FUTURE LEADERS DEVELOPMENT PROGRAMMES
# 55168        tntjobs.co.uk  QUALITY ASSURANCE ENVIRONMENTAL MANAGER  EAST ...
#
#       LocationNormalised                       Company  OpenTimeNormalised  \
# 0                DORKING  GREGORY MARTIN INTERNATIONAL 2013-07-08 12:00:00
# 1                GLASGOW  GREGORY MARTIN INTERNATIONAL 2012-01-30 00:00:00
# 2              HAMPSHIRE  GREGORY MARTIN INTERNATIONAL 2012-12-21 15:00:00
# 3                 SURREY  GREGORY MARTIN INTERNATIONAL 2013-12-08 15:00:00
# 4                 SURREY  GREGORY MARTIN INTERNATIONAL 2013-03-02 12:00:00
# ...                  ...                           ...                 ...
# 55164          SALISBURY                               2012-01-23 12:00:00
# 55165                 UK                    ABENEFIT2U 2013-08-01 15:00:00
# 55166             LONDON         FRAM EXECUTIVE SEARCH 2013-01-26 00:00:00
# 55167            HACKNEY                      BARCLAYS 2012-12-23 15:00:00
# 55168         NOTTINGHAM      STEPHEN JAMES CONSULTING 2012-01-10 15:00:00
#
#       CloseTimeNormalised  Salary_Normalised
# 0     2013-09-06 12:00:00            25000.0
# 1     2012-03-30 00:00:00            30000.0
# 2     2013-01-20 15:00:00            30000.0
# 3     2014-02-06 15:00:00            27500.0
# 4     2013-05-01 12:00:00            25000.0
# ...                   ...                ...
# 55164 2012-02-06 12:00:00            22800.0
# 55165 2013-08-31 15:00:00            24000.0
# 55166 2013-02-25 00:00:00            40000.0
# 55167 2013-02-21 15:00:00            36000.0
# 55168 2012-04-09 15:00:00            35000.0
#
# [55169 rows x 11 columns]

# %% [markdown]
# ## Format Final DataFrame

# %%
df.head()
# Out:
#          Id   ContractType ContractTime          Category            Source  \
# 0  12612628  non_specified    permanent  Engineering Jobs  cv-library.co.uk
# 1  12612830  non_specified    permanent  Engineering Jobs  cv-library.co.uk
# 2  12612844  non_specified    permanent  Engineering Jobs  cv-library.co.uk
# 3  12613049  non_specified    permanent  Engineering Jobs  cv-library.co.uk
# 4  12613647  non_specified    permanent  Engineering Jobs  cv-library.co.uk
#
#                                                Title LocationNormalised  \
# 0                        ENGINEERING SYSTEMS ANALYST            DORKING
# 1                                   STRESS ENGINEER             GLASGOW
# 2                   MODELLING AND SIMULATION ANALYST          HAMPSHIRE
# 3  ENGINEERING SYSTEMS ANALYST / MATHEMATICAL MOD...             SURREY
# 4          PIONEER MISER ENGINEERING SYSTEMS ANALYST             SURREY
#
#                         Company  OpenTimeNormalised CloseTimeNormalised  \
# 0  GREGORY MARTIN INTERNATIONAL 2013-07-08 12:00:00 2013-09-06 12:00:00
# 1  GREGORY MARTIN INTERNATIONAL 2012-01-30 00:00:00 2012-03-30 00:00:00
# 2  GREGORY MARTIN INTERNATIONAL 2012-12-21 15:00:00 2013-01-20 15:00:00
# 3  GREGORY MARTIN INTERNATIONAL 2013-12-08 15:00:00 2014-02-06 15:00:00
# 4  GREGORY MARTIN INTERNATIONAL 2013-03-02 12:00:00 2013-05-01 12:00:00
#
#    Salary_Normalised
# 0            25000.0
# 1            30000.0
# 2            30000.0
# 3            27500.0
# 4            25000.0

# %% [markdown]
# From the above:
# - Source to become SourceName
# - LocationNormalised to become Location
# - OpenTimeNormalised to become OpenDate
# - CloseTimeNormalised to become CloseDate
# - Salary Normalised to become Salary

# %%
df['SourceName'] = df['Source']
df.drop('Source', axis = 1, inplace = True)

df['Location'] = df['LocationNormalised']
df.drop('LocationNormalised', axis = 1, inplace = True)

df['OpenDate'] = df['OpenTimeNormalised']
df.drop('OpenTimeNormalised', axis = 1, inplace = True)

df['CloseDate'] = df['CloseTimeNormalised']
df.drop('CloseTimeNormalised', axis = 1, inplace = True)

df['Salary'] = df['Salary_Normalised']
df.drop('Salary_Normalised', axis = 1, inplace = True)

# %%
df.head()
# Out:
#          Id   ContractType ContractTime          Category  \
# 0  12612628  non_specified    permanent  Engineering Jobs
# 1  12612830  non_specified    permanent  Engineering Jobs
# 2  12612844  non_specified    permanent  Engineering Jobs
# 3  12613049  non_specified    permanent  Engineering Jobs
# 4  12613647  non_specified    permanent  Engineering Jobs
#
#                                                Title  \
# 0                        ENGINEERING SYSTEMS ANALYST
# 1                                   STRESS ENGINEER
# 2                   MODELLING AND SIMULATION ANALYST
# 3  ENGINEERING SYSTEMS ANALYST / MATHEMATICAL MOD...
# 4          PIONEER MISER ENGINEERING SYSTEMS ANALYST
#
#                         Company        SourceName   Location  \
# 0  GREGORY MARTIN INTERNATIONAL  cv-library.co.uk    DORKING
# 1  GREGORY MARTIN INTERNATIONAL  cv-library.co.uk    GLASGOW
# 2  GREGORY MARTIN INTERNATIONAL  cv-library.co.uk  HAMPSHIRE
# 3  GREGORY MARTIN INTERNATIONAL  cv-library.co.uk     SURREY
# 4  GREGORY MARTIN INTERNATIONAL  cv-library.co.uk     SURREY
#
#              OpenDate           CloseDate   Salary
# 0 2013-07-08 12:00:00 2013-09-06 12:00:00  25000.0
# 1 2012-01-30 00:00:00 2012-03-30 00:00:00  30000.0
# 2 2012-12-21 15:00:00 2013-01-20 15:00:00  30000.0
# 3 2013-12-08 15:00:00 2014-02-06 15:00:00  27500.0
# 4 2013-03-02 12:00:00 2013-05-01 12:00:00  25000.0

# %%
#Rearrange columns to ensure desired format for output

# %%
df = df[['Id', 'Title', 'Location', 'Company', 'ContractType', 'ContractTime', 'Category', 'Salary', 'OpenDate', 'CloseDate', 'SourceName']]

# %%
df
# Out:
#              Id                                              Title  \
# 0      12612628                        ENGINEERING SYSTEMS ANALYST
# 1      12612830                                   STRESS ENGINEER
# 2      12612844                   MODELLING AND SIMULATION ANALYST
# 3      12613049  ENGINEERING SYSTEMS ANALYST / MATHEMATICAL MOD...
# 4      12613647          PIONEER MISER ENGINEERING SYSTEMS ANALYST
# ...         ...                                                ...
# 55164  72705203                TEACHER OF BUSINESS STUDIES AND LAW
# 55165  72705205         PENSIONS ADMINISTRATORS TEMPORARY/CONTRACT
# 55166  72705221                           SENIOR FINANCIAL ADVISOR
# 55167  72705240     BARCLAYS FUTURE LEADERS DEVELOPMENT PROGRAMMES
# 55168  72705244  QUALITY ASSURANCE ENVIRONMENTAL MANAGER  EAST ...
#
#          Location                       Company   ContractType   ContractTime  \
# 0         DORKING  GREGORY MARTIN INTERNATIONAL  non_specified      permanent
# 1         GLASGOW  GREGORY MARTIN INTERNATIONAL  non_specified      permanent
# 2       HAMPSHIRE  GREGORY MARTIN INTERNATIONAL  non_specified      permanent
# 3          SURREY  GREGORY MARTIN INTERNATIONAL  non_specified      permanent
# 4          SURREY  GREGORY MARTIN INTERNATIONAL  non_specified      permanent
# ...           ...                           ...            ...            ...
# 55164   SALISBURY                                non_specified       contract
# 55165          UK                    ABENEFIT2U  non_specified       contract
# 55166      LONDON         FRAM EXECUTIVE SEARCH  non_specified      permanent
# 55167     HACKNEY                      BARCLAYS  non_specified  non-specified
# 55168  NOTTINGHAM      STEPHEN JAMES CONSULTING  non_specified      permanent
#
#                         Category   Salary            OpenDate  \
# 0               Engineering Jobs  25000.0 2013-07-08 12:00:00
# 1               Engineering Jobs  30000.0 2012-01-30 00:00:00
# 2               Engineering Jobs  30000.0 2012-12-21 15:00:00
# 3               Engineering Jobs  27500.0 2013-12-08 15:00:00
# 4               Engineering Jobs  25000.0 2013-03-02 12:00:00
# ...                          ...      ...                 ...
# 55164              Teaching Jobs  22800.0 2012-01-23 12:00:00
# 55165  Accounting & Finance Jobs  24000.0 2013-08-01 15:00:00
# 55166  Accounting & Finance Jobs  40000.0 2013-01-26 00:00:00
# 55167                    IT Jobs  36000.0 2012-12-23 15:00:00
# 55168  Healthcare & Nursing Jobs  35000.0 2012-01-10 15:00:00
#
#                 CloseDate           SourceName
# 0     2013-09-06 12:00:00     cv-library.co.uk
# 1     2012-03-30 00:00:00     cv-library.co.uk
# 2     2013-01-20 15:00:00     cv-library.co.uk
# 3     2014-02-06 15:00:00     cv-library.co.uk
# 4     2013-05-01 12:00:00     cv-library.co.uk
# ...                   ...                  ...
# 55164 2012-02-06 12:00:00           hays.co.uk
# 55165 2013-08-31 15:00:00     cv-library.co.uk
# 55166 2013-02-25 00:00:00  ifaonlinejobs.co.uk
# 55167 2013-02-21 15:00:00           grb.uk.com
# 55168 2012-04-09 15:00:00        tntjobs.co.uk
#
# [55169 rows x 11 columns]

# %% [markdown]
# # Final Data Frame
# <br> Below is the celaned data frame, we will simply print it out to see what it looks like.

# %%
df
# Out:
#              Id                                              Title  \
# 0      12612628                        ENGINEERING SYSTEMS ANALYST
# 1      12612830                                   STRESS ENGINEER
# 2      12612844                   MODELLING AND SIMULATION ANALYST
# 3      12613049  ENGINEERING SYSTEMS ANALYST / MATHEMATICAL MOD...
# 4      12613647          PIONEER MISER ENGINEERING SYSTEMS ANALYST
# ...         ...                                                ...
# 55164  72705203                TEACHER OF BUSINESS STUDIES AND LAW
# 55165  72705205         PENSIONS ADMINISTRATORS TEMPORARY/CONTRACT
# 55166  72705221                           SENIOR FINANCIAL ADVISOR
# 55167  72705240     BARCLAYS FUTURE LEADERS DEVELOPMENT PROGRAMMES
# 55168  72705244  QUALITY ASSURANCE ENVIRONMENTAL MANAGER  EAST ...
#
#          Location                       Company   ContractType   ContractTime  \
# 0         DORKING  GREGORY MARTIN INTERNATIONAL  non_specified      permanent
# 1         GLASGOW  GREGORY MARTIN INTERNATIONAL  non_specified      permanent
# 2       HAMPSHIRE  GREGORY MARTIN INTERNATIONAL  non_specified      permanent
# 3          SURREY  GREGORY MARTIN INTERNATIONAL  non_specified      permanent
# 4          SURREY  GREGORY MARTIN INTERNATIONAL  non_specified      permanent
# ...           ...                           ...            ...            ...
# 55164   SALISBURY                                non_specified       contract
# 55165          UK                    ABENEFIT2U  non_specified       contract
# 55166      LONDON         FRAM EXECUTIVE SEARCH  non_specified      permanent
# 55167     HACKNEY                      BARCLAYS  non_specified  non-specified
# 55168  NOTTINGHAM      STEPHEN JAMES CONSULTING  non_specified      permanent
#
#                         Category   Salary            OpenDate  \
# 0               Engineering Jobs  25000.0 2013-07-08 12:00:00
# 1               Engineering Jobs  30000.0 2012-01-30 00:00:00
# 2               Engineering Jobs  30000.0 2012-12-21 15:00:00
# 3               Engineering Jobs  27500.0 2013-12-08 15:00:00
# 4               Engineering Jobs  25000.0 2013-03-02 12:00:00
# ...                          ...      ...                 ...
# 55164              Teaching Jobs  22800.0 2012-01-23 12:00:00
# 55165  Accounting & Finance Jobs  24000.0 2013-08-01 15:00:00
# 55166  Accounting & Finance Jobs  40000.0 2013-01-26 00:00:00
# 55167                    IT Jobs  36000.0 2012-12-23 15:00:00
# 55168  Healthcare & Nursing Jobs  35000.0 2012-01-10 15:00:00
#
#                 CloseDate           SourceName
# 0     2013-09-06 12:00:00     cv-library.co.uk
# 1     2012-03-30 00:00:00     cv-library.co.uk
# 2     2013-01-20 15:00:00     cv-library.co.uk
# 3     2014-02-06 15:00:00     cv-library.co.uk
# 4     2013-05-01 12:00:00     cv-library.co.uk
# ...                   ...                  ...
# 55164 2012-02-06 12:00:00           hays.co.uk
# 55165 2013-08-31 15:00:00     cv-library.co.uk
# 55166 2013-02-25 00:00:00  ifaonlinejobs.co.uk
# 55167 2013-02-21 15:00:00           grb.uk.com
# 55168 2012-04-09 15:00:00        tntjobs.co.uk
#
# [55169 rows x 11 columns]

# %% [markdown]
# ## Saving Data

# %% [markdown]
# ## Export to CSV

# %%
df.to_csv('dataset1_solution.csv', index = False)

# %%
#Check output is as expected
check_df = pd.read_csv('dataset1_solution.csv')
check_df.head()
# Out:
#          Id                                              Title   Location  \
# 0  12612628                        ENGINEERING SYSTEMS ANALYST    DORKING
# 1  12612830                                   STRESS ENGINEER     GLASGOW
# 2  12612844                   MODELLING AND SIMULATION ANALYST  HAMPSHIRE
# 3  12613049  ENGINEERING SYSTEMS ANALYST / MATHEMATICAL MOD...     SURREY
# 4  12613647          PIONEER MISER ENGINEERING SYSTEMS ANALYST     SURREY
#
#                         Company   ContractType ContractTime          Category  \
# 0  GREGORY MARTIN INTERNATIONAL  non_specified    permanent  Engineering Jobs
# 1  GREGORY MARTIN INTERNATIONAL  non_specified    permanent  Engineering Jobs
# 2  GREGORY MARTIN INTERNATIONAL  non_specified    permanent  Engineering Jobs
# 3  GREGORY MARTIN INTERNATIONAL  non_specified    permanent  Engineering Jobs
# 4  GREGORY MARTIN INTERNATIONAL  non_specified    permanent  Engineering Jobs
#
#     Salary             OpenDate            CloseDate        SourceName
# 0  25000.0  2013-07-08 12:00:00  2013-09-06 12:00:00  cv-library.co.uk
# 1  30000.0  2012-01-30 00:00:00  2012-03-30 00:00:00  cv-library.co.uk
# 2  30000.0  2012-12-21 15:00:00  2013-01-20 15:00:00  cv-library.co.uk
# 3  27500.0  2013-12-08 15:00:00  2014-02-06 15:00:00  cv-library.co.uk
# 4  25000.0  2013-03-02 12:00:00  2013-05-01 12:00:00  cv-library.co.uk

# %% [markdown]
# ## Summary
#
# The data set has been cleaned so that it is now able to be processed in a later notebook. Some things we did:
# <br> Checked for semantically identical titles and decriptions by using NLP tools to check frequencies of items.
# <br> Cleaned up different formatting of the same item, e.g. "Software Engineer" and "software engineer"
# <br> Made date formated more easily readable
# <br> Used our judgement to make certain assumptions and understand the limits of our data cleaning. E.g. if no contract type was specified, we listed it as such and couldn't infer that it was something else.
